# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus("Adanian123@@@")

engine = create_engine(
    f"mysql+pymysql://root:{password}@localhost/olist_db"
)

# %%
with engine.connect() as conn:
    print("Connection OK")
# Out:
# Connection OK

# %%
customers = pd.read_csv(r"C:\Users\hp\Desktop\olist_db\olist_customers_dataset.csv")
customers.to_sql("customers", engine, if_exists="replace", index=False)
print("customers loaded")
# Out:
# customers loaded

# %%
orders = pd.read_csv(r"C:\Users\hp\Desktop\olist_db\olist_orders_dataset.csv")
orders.to_sql("orders", engine, if_exists="replace", index=False)
# Out:
# 99441

# %%
order_items = pd.read_csv(r"C:\Users\hp\Desktop\olist_db\olist_order_items_dataset.csv")
payments = pd.read_csv(r"C:\Users\hp\Desktop\olist_db\olist_order_payments_dataset.csv")
products = pd.read_csv(r"C:\Users\hp\Desktop\olist_db\olist_products_dataset.csv")
sellers = pd.read_csv(r"C:\Users\hp\Desktop\olist_db\olist_sellers_dataset.csv")
reviews = pd.read_csv(r"C:\Users\hp\Desktop\olist_db\olist_order_reviews_dataset.csv")
geolocation = pd.read_csv(r"C:\Users\hp\Desktop\olist_db\olist_geolocation_dataset.csv")
category_translation = pd.read_csv(r"C:\Users\hp\Desktop\olist_db\product_category_name_translation.csv")

# %%
order_items.to_sql("order_items", engine, if_exists="replace", index=False)
payments.to_sql("order_payments", engine, if_exists="replace", index=False)
products.to_sql("products", engine, if_exists="replace", index=False)
sellers.to_sql("sellers", engine, if_exists="replace", index=False)
reviews.to_sql("order_reviews", engine, if_exists="replace", index=False)
geolocation.to_sql("geolocation", engine, if_exists="replace", index=False)
category_translation.to_sql("product_category_translation", engine, if_exists="replace", index=False)
# Out:
# 71

# %%
reviews.to_sql("order_reviews", engine, if_exists="replace", index=False)
# Out:
# 99224
